# %% [markdown]
# # Continuous Time-Independent Schrödinger Equation
#
# Consider the one-dimensional quantum harmonic oscillator defined by the Hamiltonian:
#
# $
# H = \hat{p}^2 + \omega^2 \hat{q}^2
# $
#
# (a) Write a program to compute the first $k$ eigenvalues $E_k$ and eigenvectors $|\Psi_k\rangle$.<br>
# (b) How would you rate your program in terms of the priorities we introduced in class for good scientific software development?
#
# 1. **Correctness**
# 2. **Stability**
# 3. **Accurate Discretization**
# 4. **Flexibility**
# 5. **Efficiency**

# %%
import qho_functions as qho

# %% [markdown]
# ## Exercise (a)

# %%
# PARAMETERS:

omega = 1     # Angular frequency
L = 5         # Range of x from -L to L
N = 1000      # Number of grid points
k = 8         # Number of eigenvalues
order = 2     # Approximation order

# %%
energies, _ = qho.harmonic_oscillator_spectrum(omega, L, N, order)
print(f'First {k} eigenvalues for second order finite method solution, with omega = {omega}:\n {energies[:k]}')
# Out:
# First 8 eigenvalues for second order finite method solution, with omega = 1:
#  [0.50049737 1.50148585 2.50246187 3.50342637 4.50438804 5.50540798
#  6.50681305 7.50994997]

# %%
qho.plot_wf_en(omega, L, N, k, order)

# %%
# PARAMETERS:

omega = 2     # Angular frequency
L = 5         # Range of x from -L to L
N = 2000      # Number of grid points
k = 10         # Number of eigenvalues
order = 2     # Approximation order

# %%
energies, _ = qho.harmonic_oscillator_spectrum(omega, L, N, order)
print(f'First {k} eigenvalues for second order finite method solution, with omega = {omega}:\n {energies[:k]}')
# Out:
# First 10 eigenvalues for second order finite method solution, with omega = 2:
#  [ 1.00049712  3.00148511  5.00246058  7.00342355  9.004374   11.00531193
#  13.00623736 15.00715027 17.00805066 19.00893855]

# %%
qho.plot_wf_en(omega, L, N, k, order)

# %% [markdown]
# ## Exercise (b)

# %% [markdown]
# ### 1a. **Correctness**: Schroedinger equation check

# %%
# PARAMETERS:

omega = 1             # Angular frequency
L = 5                 # Range of x from -L to L
N = 1000              # Number of grid points
k = 20                # Number of eigenvalues
orders = [2, 4, 6]    # Approximation order

# %%
qho.plot_schroedinger(omega, L, N, k, orders)

# %% [markdown]
# ### 1b. **Correctness**: comparison with analytical solution

# %%
# PARAMETERS:

omega = 1     # Angular frequency
L = 5         # Range of x from -L to L
N = 1000      # Number of grid points
k = 8         # Number of eigenvalues

# %%
analytical_energies = [qho.harmonic_en(omega, k) for k in range(0, k)]
print(f'First {k} eigenvalues for analytical solution with omega = {omega}:\n {analytical_energies[:k]}')
# Out:
# First 8 eigenvalues for analytical solution with omega = 1:
#  [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]

# %%
qho.plot_wf_en(omega, L, N, k)

# %%
# PARAMETERS:

omega = 2     # Angular frequency
L = 5         # Range of x from -L to L
N = 2000      # Number of grid points
k = 8         # Number of eigenvalues

# %%
analytical_energies = [qho.harmonic_en(omega, k) for k in range(0, k)]
print(f'First {k} eigenvalues for analytical solution with omega = {omega}:\n {analytical_energies[:k]}')
# Out:
# First 8 eigenvalues for analytical solution with omega = 2:
#  [1.0, 3.0, 5.0, 7.0, 9.0, 11.0, 13.0, 15.0]

# %%
qho.plot_wf_en(omega, L, N, k)

# %%
L = 5
N = 1000
omega = 1
k = 16
orders = [2, 4, 6, 8]

# %%
qho.plot_wfc_orders(omega, L, N, k, orders)

# %%
qho.plot_energy_orders(omega, L, N, k, orders)

# %%
qho.plot_loglog_fit(omega, L, N, k=1000, order=2)
# Out:
# Log-Log Fit Parameters: Intercept = -2.04, Slope = 2.21, R^2 = 0.939

# %% [markdown]
# ### 2. **Stability**: check on different runs

# %%
L = 5
N = 1000
omega = 1
k = 16
orders = [2, 4, 6]
num_runs = 100

# %%
qho.plot_stability(omega, L, N, k, orders, num_runs)

# %%
L = 5
N = 1000
omega = 5
k = 16
orders = [2, 4, 6]
num_runs = 100

# %%
qho.plot_stability(omega, L, N, k, orders, num_runs)

# %% [markdown]
# ### 3. **Accurate discretization**: different discretization steps

# %%
omega = 1
L = 5
k = 16
orders = [2, 4, 6]
N_values = [100, 200, 500, 1000, 2000, 5000]

# %%
qho.plot_discretization_heatmaps(omega, L, k, orders, N_values)

# %%
omega = 5
L = 5
k = 16
orders = [2, 4, 6]
N_values = [100, 200, 500, 1000, 2000, 5000]

# %%
qho.plot_discretization_heatmaps(omega, L, k, orders, N_values)

# %% [markdown]
# ### 4. **Flexibility**: Higher orders

# %%
import qho_functions as qho

# %%
L = 5
N = 1000
omega = 1
k = 8
orders = [2, 4, 6, 8]

# %%
for order in orders:
  qho.plot_wf_en(omega, L, N, k, order)

# %% [markdown]
# ### 4. **Efficiency**: runtimes

# %%
omega = 1
L = 5
orders = [2, 4, 6, 8]
N_values = [100, 200, 500, 1000, 2000]
reps = 20

# %%
qho.plot_efficiency_heatmap(omega, L, orders, N_values, reps)

# %%
omega = 5
L = 5
orders = [2, 4, 6, 8]
N_values = [100, 200, 500, 1000, 2000]
reps = 20

# %%
qho.plot_efficiency_heatmap(omega, L, orders, N_values, reps)
